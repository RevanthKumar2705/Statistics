# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as stats

# %%
np.random.seed(12)

races =   ["asian","black","hispanic","other","white"]

# Generate random data
voter_race = np.random.choice(a= races,
                              p = [0.05, 0.15 ,0.25, 0.05, 0.5],
                              size=1000)

voter_age = stats.poisson.rvs(loc=18,
                              mu=30,
                              size=1000)

# Group age data by race
voter_frame = pd.DataFrame({"race":voter_race,"age":voter_age})
groups = voter_frame.groupby("race").groups

# Extract individual groups
asian = voter_age[groups["asian"]]
black = voter_age[groups["black"]]
hispanic = voter_age[groups["hispanic"]]
other = voter_age[groups["other"]]
white = voter_age[groups["white"]]

# Perform the ANOVA
stats.f_oneway(asian, black, hispanic, other, white)
# Out:
# F_onewayResult(statistic=1.7744689357329695, pvalue=0.13173183201930463)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
voter_race
# Out:
# array(['black', 'white', 'hispanic', 'white', 'asian', 'white', 'white',
#        'asian', 'white', 'black', 'hispanic', 'white', 'white', 'white',
#        'asian', 'white', 'white', 'other', 'white', 'black', 'white',
#        'asian', 'black', 'black', 'hispanic', 'white', 'other', 'white',
#        'hispanic', 'white', 'white', 'hispanic', 'hispanic', 'white',
#        'white', 'white', 'white', 'white', 'hispanic', 'other',
#        'hispanic', 'white', 'black', 'white', 'hispanic', 'hispanic',
#        'other', 'hispanic', 'other', 'asian', 'black', 'white', 'white',
#        'asian', 'hispanic', 'hispanic', 'black', 'white', 'hispanic',
#        'asian', 'white', 'white', 'black', 'hispanic', 'white', 'other',
#        'white', 'other', 'white', 'white', 'white', 'hispanic', 'other',
#        'white', 'hispanic', 'white', 'black', 'white', 'asian', 'white',
#        'white', 'white', 'white', 'hispanic', 'white', 'white', 'white',
#        'hispanic', 'hispanic', 'hispanic', 'white', 'hispanic', 'white',
#        'white', 'white', 'asian', 'white', 'white', 'asian', 'white',
#        'hispanic', 'white', 'white', 'white', 'hispanic', 'black',
#        'white', 'white', 'black', 'hispanic', 'hispanic', 'hispanic',
#        'white', 'hispanic', 'hispanic', 'white', 'white', 'hispanic',
#        'white', 'black', 'black', 'hispanic', 'white', 'hispanic',
#        'black', 'white', 'black', 'white', 'hispanic', 'white', 'white',
#        'black', 'hispanic', 'hispanic', 'black', 'asian', 'asian',
#        'white', 'black', 'hispanic', 'white', 'white', 'white', 'black',
#        'hispanic', 'hispanic', 'other', 'white', 'hispanic', 'white',
#        'white', 'white', 'black', 'white', 'white', 'hispanic',
#        'hispanic', 'white', 'hispanic', 'hispanic', 'white', 'white',
#        'asian', 'white', 'white', 'white', 'white', 'black', 'hispanic',
#        'hispanic', 'white', 'black', 'hispanic', 'hispanic', 'white',
#        'white', 'white', 'white', 'black', 'white', 'white', 'white',
#        'black', 'white', 'black', 'white', 'white', 'white', 'hispanic',
#        'white', 'white', 'hispanic', 'white', 'white', 'white',
#        'hispanic', 'white', 'white', 'white', 'white', 'white', 'white',
#        'black', 'asian', 'white', 'white', 'black', 'white', 'white',
#        'hispanic', 'hispanic', 'black', 'white', 'black', 'white',
#        'white', 'white', 'hispanic', 'hispanic', 'white', 'hispanic',
#        'white', 'white', 'hispanic', 'hispanic', 'white', 'white',
#        'asian', 'white', 'black', 'white', 'hispanic', 'white', 'black',
#        'white', 'hispanic', 'black', 'other', 'black', 'white',
#        'hispanic', 'hispanic', 'black', 'black', 'white', 'black',
#        'hispanic', 'white', 'white', 'black', 'black', 'hispanic',
#        'black', 'white', 'white', 'asian', 'white', 'black', 'white',
#        'hispanic', 'hispanic', 'hispanic', 'hispanic', 'white',
#        'hispanic', 'white', 'white', 'hispanic', 'white', 'black',
#        'white', 'hispanic', 'white', 'black', 'white', 'white', 'white',
#        'white', 'white', 'white', 'white', 'other', 'white', 'white',
#        'white', 'white', 'white', 'white', 'hispanic', 'white', 'white',
#        'hispanic', 'white', 'hispanic', 'other', 'white', 'white',
#        'other', 'white', 'black', 'asian', 'hispanic', 'white',
#        'hispanic', 'black', 'white', 'black', 'hispanic', 'white',
#        'asian', 'white', 'hispanic', 'hispanic', 'hispanic', 'black',
#        'white', 'hispanic', 'hispanic', 'white', 'black', 'hispanic',
#        'white', 'hispanic', 'black', 'hispanic', 'white', 'black',
#        'white', 'white', 'other', 'black', 'white', 'hispanic', 'white',
#        'white', 'white', 'white', 'white', 'other', 'white', 'black',
#        'white', 'black', 'white', 'asian', 'white', 'white', 'black',
#        'black', 'white', 'other', 'white', 'hispanic', 'white', 'asian',
#        'white', 'white', 'hispanic'], dtype='<U8')

# %%
voter_age
# Out:
# array([51, 49, 51, 48, 56, 40, 51, 52, 39, 57, 50, 50, 49, 52, 37, 36, 46,
#        48, 37, 49, 50, 50, 61, 53, 48, 43, 49, 44, 45, 52, 51, 48, 48, 54,
#        49, 62, 45, 56, 47, 49, 47, 55, 49, 54, 49, 46, 47, 55, 48, 53, 43,
#        43, 52, 47, 45, 49, 55, 51, 59, 56, 48, 53, 52, 46, 46, 58, 43, 48,
#        56, 50, 50, 45, 44, 46, 58, 48, 50, 44, 43, 48, 46, 54, 40, 47, 44,
#        49, 53, 48, 48, 41, 48, 45, 48, 37, 51, 46, 50, 56, 54, 47, 45, 52,
#        51, 53, 42, 41, 48, 45, 51, 44, 46, 39, 49, 53, 52, 50, 53, 44, 55,
#        49, 45, 59, 53, 57, 51, 51, 46, 43, 59, 46, 46, 45, 44, 49, 42, 45,
#        54, 46, 41, 44, 40, 39, 52, 50, 51, 51, 45, 47, 48, 52, 42, 61, 42,
#        51, 50, 50, 55, 53, 53, 43, 46, 51, 42, 55, 51, 53, 48, 43, 50, 43,
#        42, 50, 49, 55, 46, 51, 60, 53, 50, 46, 43, 40, 42, 45, 48, 49, 51,
#        47, 48, 52, 40, 54, 48, 49, 46, 53, 39, 53, 43, 51, 48, 44, 45, 44,
#        42, 46, 44, 39, 45, 42, 49, 44, 43, 60, 40, 58, 48, 40, 47, 52, 45,
#        41, 45, 46, 54, 54, 46, 55, 43, 56, 48, 47, 45, 47, 48, 65, 43, 42,
#        44, 44, 50, 49, 45, 52, 43, 45, 40, 43, 44, 52, 46, 54, 40, 43, 38,
#        44, 45, 49, 44, 43, 48, 38, 52, 48, 50, 52, 47, 55, 56, 43, 52, 57,
#        50, 53, 39, 47, 51, 54, 45, 47, 53, 47, 45, 38, 47, 53, 49, 41, 40,
#        49, 44, 49, 45, 46, 61, 50, 56, 58, 49, 44, 51, 48, 45, 40, 48, 43,
#        52, 45, 49, 41, 44, 50, 45, 60, 45, 46, 53, 48, 51, 48, 44, 35, 55,
#        44, 43, 48, 51, 40, 46, 57, 43, 50, 48, 41, 56, 57, 46, 42, 53, 42,
# %%
import statsmodels.api as sm
from statsmodels.formula.api import ols

model = ols('age ~ race',                 # Model formula
            data = voter_frame).fit()
                
anova_result = sm.stats.anova_lm(model, typ=2)
print (anova_result)
# Out:
#              sum_sq     df         F    PR(>F)
# race        199.369    4.0  1.774469  0.131732
# Residual  27948.102  995.0       NaN       NaN

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
np.random.seed(12)

# Generate random data
voter_race = np.random.choice(a= races,
                              p = [0.05, 0.15 ,0.25, 0.05, 0.5],
                              size=1000)

# Use a different distribution for white ages
white_ages = stats.poisson.rvs(loc=18, 
                              mu=32,
                              size=1000)

voter_age = stats.poisson.rvs(loc=18,
                              mu=30,
                              size=1000)

voter_age = np.where(voter_race=="white", white_ages, voter_age)

# Group age data by race
voter_frame = pd.DataFrame({"race":voter_race,"age":voter_age})
groups = voter_frame.groupby("race").groups   

# Extract individual groups
asian = voter_age[groups["asian"]]
black = voter_age[groups["black"]]
hispanic = voter_age[groups["hispanic"]]
other = voter_age[groups["other"]]
white = voter_age[groups["white"]]

# Perform the ANOVA
stats.f_oneway(asian, black, hispanic, other, white)
# Out:
# F_onewayResult(statistic=10.164699828386366, pvalue=4.5613242113994585e-08)

# %%
# Alternate method
model = ols('age ~ race',                 # Model formula
            data = voter_frame).fit()
                
anova_result = sm.stats.anova_lm(model, typ=2)
print (anova_result)
# Out:
#                 sum_sq     df        F        PR(>F)
# race       1284.123213    4.0  10.1647  4.561324e-08
# Residual  31424.995787  995.0      NaN           NaN

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Get all race pairs
race_pairs = []

for race1 in range(4):
    for race2  in range(race1+1,5):
        race_pairs.append((races[race1], races[race2]))

# Conduct t-test on each pair
for race1, race2 in race_pairs: 
    print(race1, race2)
    print(stats.ttest_ind(voter_age[groups[race1]], 
                          voter_age[groups[race2]]))
# Out:
# asian black
# Ttest_indResult(statistic=0.8386446909747979, pvalue=0.4027281369339345)
# asian hispanic
# Ttest_indResult(statistic=-0.42594691924932293, pvalue=0.6704669004240726)
# asian other
# Ttest_indResult(statistic=0.9795284739636, pvalue=0.3298877500095151)
# asian white
# Ttest_indResult(statistic=-2.318108811252288, pvalue=0.020804701566400217)
# black hispanic
# Ttest_indResult(statistic=-1.9527839210712925, pvalue=0.05156197171952594)
# black other
# Ttest_indResult(statistic=0.28025754367057176, pvalue=0.7795770111117659)
# black white
# Ttest_indResult(statistic=-5.379303881281834, pvalue=1.0394212166624012e-07)
# hispanic other
# Ttest_indResult(statistic=1.5853626170340225, pvalue=0.11396630528484335)
# hispanic white
# Ttest_indResult(statistic=-3.5160312714115376, pvalue=0.0004641298649066684)
# other white
# Ttest_indResult(statistic=-3.763809322077872, pvalue=0.00018490576317593065)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from statsmodels.stats.multicomp import pairwise_tukeyhsd

tukey = pairwise_tukeyhsd(endog=voter_age,     # Data
                          groups=voter_race,   # Groups
                          alpha=0.05)          # Significance level

tukey.plot_simultaneous()    # Plot group confidence intervals
plt.vlines(x=49.57,ymin=-0.5,ymax=4.5, color="red")

tukey.summary()              # See test summary
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %% [markdown]
# ![image.png](attachment:image.png)
